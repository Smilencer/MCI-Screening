# %%
import numpy as np
import tensorflow as tf

# %%
a=np.array([0.01,0.037,0.06,0.01])

# %%
a
# Out:
# array([0.01 , 0.037, 0.06 , 0.01 ])

# %%
a=1/a

# %%
a
# Out:
# array([100.        ,  27.02702703,  16.66666667, 100.        ])

# %%
a=(a/100)

# %%
a
# Out:
# array([1.        , 0.27027027, 0.16666667, 1.        ])
